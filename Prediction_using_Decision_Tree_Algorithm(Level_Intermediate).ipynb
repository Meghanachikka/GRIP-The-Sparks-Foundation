# %% [markdown]
# # Graduate Rotational Internship Program (GRIP)
# **The Sparks foundation Data Science & Business Analytics Tasks**
#
# Task_2 : Prediction using Decision Tree Algorithm(Level - Intermediate)
#
# Author : Meghana.Ch
#
# Tool : Python
#
# IDE : Google colab
#
# Dataset : https://bit.ly/3kXTdox

# %% [markdown]
# ![WhatsApp Image 2021-07-19 at 9.04.46 PM.jpeg](data:image/jpeg;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import numpy as np
from scipy.spatial.distance import euclidean

# %%
iris=load_iris()
features= iris.data
label=iris.target

# %%
features.shape
# Out:
# (150, 4)

# %%
print(iris.feature_names)
print(iris.target_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# **We will be using the iris dataset to build a decision tree classifier. The data set contains information of 3 classes of the iris plant with the following attributes: - sepal length - sepal width - petal length - petal width. The task is to predict the class of the iris plant based on the attributes**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(features,label,test_size=0.25)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
clf=DecisionTreeClassifier()

# %%
test_x=features[[0,50,100]]
test_y=label[[0,50,100]]

# %%
test_x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.3, 3.3, 6. , 2.5]])

# %%
test_y
# Out:
# array([0, 1, 2])

# %% [markdown]
# **When we initiate the Decision Tree Classifier, by-default the criterion parameters is set to ‘gini’, and there are various other parameters as well, which we can go with the default or change it if required. Will see what impact of it when change one or two parameters.**

# %%
clf.fit(x,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris")
# Out:
# 'iris.pdf'

# %% [markdown]
# **Here I have used the default classifier which is clf, thus in the tree we see the gini values.**

# %% [markdown]
# ## THANK YOU
